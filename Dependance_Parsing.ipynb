# %% [markdown]
# <a href="https://colab.research.google.com/github/vvrgit/NLP-LAB/blob/main/Dependance_Parsing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("Ram eats an apple")

for token in doc:
    print(token.text, token.dep_, token.head.text)
# Out:
# Ram nsubj eats
# eats ROOT eats
# an det apple
# apple dobj eats
