# %% [markdown]
# <a href="https://colab.research.google.com/github/vvrgit/NLP-LAB/blob/main/PoS_Tagging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Parts of Speech (POS)** tagging is the process of assigning a grammatical category (such as noun, verb, adjective, etc.) to each word (token) in a sentence based on its definition and context.
#
# **It answers the question:** What role does each word play in this sentence?

# %% [markdown]
# | Category          | Description     | Example     |
# | ----------------- | --------------- | ----------- |
# | Noun (NN)         | Name of entity  | student, AI |
# | Verb (VB)         | Action or state | run, learn  |
# | Adjective (JJ)    | Describes noun  | smart, new  |
# | Adverb (RB)       | Describes verb  | quickly     |
# | Pronoun (PRP)     | Replaces noun   | he, they    |
# | Preposition (IN)  | Shows relation  | in, on      |
# | Determiner (DT)   | Limits noun     | the, a      |
# | Conjunction (CC)  | Connects words  | and, but    |
# | Interjection (UH) | Emotion         | wow, omg    |

# %% [markdown]
# PoS Tagging helps
#
#
#
# *   Helps understand sentence structure
# *   Essential for Named Entity Recognition (NER)
# *   Used in information extraction, sentiment analysis, and machine translation

# %% [markdown]
# **POS Tagging Example**
#
# Sentence: "Students are learning Natural Language Processing."

# %% [markdown]
# | Word       | POS |
# | ---------- | --- |
# | Students   | NNS |
# | are        | VBP |
# | learning   | VBG |
# | Natural    | JJ  |
# | Language   | NN  |
# | Processing | NN  |

# %% [markdown]
# NLTK uses the Penn Treebank tag set

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_eng')

sentence = "Students are learning Natural Language Processing"
tokens = nltk.word_tokenize(sentence)
pos_tags = nltk.pos_tag(tokens)

print(pos_tags)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [('Students', 'NNS'), ('are', 'VBP'), ('learning', 'VBG'), ('Natural', 'NNP'), ('Language', 'NNP'), ('Processing', 'NNP')]

# %% [markdown]
# **en_core_web_sm** is a spaCy English language model.

# %% [markdown]
# The model **en_core_wen_sm** includes:
#
# *   Part-of-Speech (POS) tagging
# *   Lemmatization
# *   Named Entity Recognition (NER)
# *   Tokenization
#
# It does NOT include word vectors (embeddings). For vectors, you need **en_core_web_md** or **en_core_web_lg**
#
# spaCy uses **Universal POS tags** (simpler & semantic)
#
# spaCy performs better for tweets, captions, and informal text.

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

doc = nlp("Students are learning Natural Language Processing")
for token in doc:
    print(token.text, token.pos_)
# Out:
# Students NOUN
# are AUX
# learning VERB
# Natural PROPN
# Language PROPN
# Processing NOUN

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying a startup in India.")

for token in doc:
    print(token.text, token.pos_, token.tag_)
# Out:
# Apple PROPN NNP
# is AUX VBZ
# looking VERB VBG
# at ADP IN
# buying VERB VBG
# a DET DT
# startup NOUN NN
# in ADP IN
# India PROPN NNP
# . PUNCT .

# %% [markdown]
# POS Tagging for Social Media Text
# | Token | NLTK Tag | spaCy Tag |
# | ----- | -------- | --------- |
# | OMG   | NNP      | INTJ      |
# | lol   | NN       | INTJ      |
# | 😂    | NN       | SYM       |
# | #AI   | NN       | PROPN     |

# %% [markdown]
# | Token | Meaning       | NLTK Tag | spaCy Tag |
# | ----- | ------------- | -------- | --------- |
# | lol   | laughing      | NN       | INTJ      |
# | omg   | surprise      | NNP      | INTJ      |
# | rn    | right now     | NN       | ADV       |
# | idk   | I don’t know  | NN       | VERB      |
# | lit   | excellent     | JJ       | ADJ       |
# | 😂    | emotion       | NN       | SYM       |
# | #AI   | hashtag/topic | NN       | PROPN     |

# %%
import spacy
from collections import Counter

nlp = spacy.load("en_core_web_sm")

text = "Loving the new AI features 😍 #AI #MachineLearning"
doc = nlp(text)

nouns = []
verbs = []

for token in doc:
    if token.pos_ in ["NOUN", "PROPN"]:
        nouns.append(token.text)
    elif token.pos_ == "VERB":
        verbs.append(token.text)

noun_freq = Counter(nouns)
verb_freq = Counter(verbs)

print("Noun Frequency:", noun_freq)
print("Verb Frequency:", verb_freq)
# Out:
# Noun Frequency: Counter({'AI': 2, '😍': 1, 'MachineLearning': 1})
# Verb Frequency: Counter({'Loving': 1, 'features': 1})

# %%
import nltk
from collections import Counter

# Assuming 'tokens' is already available from previous steps and contains all words
# If not, it would need to be created from 'texts' like this:
# all_tokens = []
# for text_item in texts:
#     all_tokens.extend(nltk.word_tokenize(text_item))
# tokens = all_tokens

pos_tags_nltk = nltk.pos_tag(tokens)

nouns_nltk = []
verbs_nltk = []

for word, tag in pos_tags_nltk:
    if tag.startswith('NN'): # NLTK tags for nouns (NN, NNS, NNP, NNPS)
        nouns_nltk.append(word)
    elif tag.startswith('VB'): # NLTK tags for verbs (VB, VBD, VBG, VBN, VBP, VBZ)
        verbs_nltk.append(word)

noun_freq_nltk = Counter(nouns_nltk)
verb_freq_nltk = Counter(verbs_nltk)

print("NLTK Noun Frequency:", noun_freq_nltk)
print("NLTK Verb Frequency:", verb_freq_nltk)
# Out:
# NLTK Noun Frequency: Counter({'t': 13, '>': 11, '’': 10, 'time': 9, 'है': 9, 'job': 8, 'people': 8, 'AI': 8, 'manager': 7, 'क्या': 7, 'la': 7, 'para': 7, 'في': 7, 'LinkedIn': 6, 'someone': 6, 'parents': 6, 'में': 6, 's': 5, 'hai': 5, 'growth': 5, 'العمل': 5, 'के': 5, 'और': 5, 'worth': 4, 'end': 4, 'rejection': 4, 'way': 4, 'things': 4, 'company': 4, 'companies': 4, 'day': 4, 'work': 4, 'LPA': 4, 'strategy': 4, 'balance': 4, 'है।': 4, 'que': 4, 'des': 4, 'এবং': 4, 'A': 4, 'é': 4, 'rahe': 4, 'hain': 4, '%': 3, 'breathe': 3, 'jobs': 3, 'ke': 3, 'something': 3, 'brand': 3, 'son': 3, '–': 3, 'success': 3, 'Lots': 3, "'well": 3, 'issue': 3, 'ways': 3, 'clients': 3, 'quality': 3, 'problems': 3, 'से': 3, 'की': 3, 'हैं': 3, 'सकता': 3, 'La': 3, 'Desde': 3, 'hasta': 3, 'está': 3, 'dans': 3, 'بيئة': 3, 'من': 3, 'Como': 3, 'в': 3, 'и': 3, 'Hinglish': 3, 'को': 3, 'कर': 3, 'कार्यस्थल': 3, 'भी': 3, 'الاصطناعي': 3, 'প্রযুক্তির': 3, 'Influencer': 2, 'profile': 2, 'posts': 2, 'application': 2, 'skills': 2, 'system': 2, 'health': 2, 'dream': 2, 'promises': 2, 'role': 2, 'baat': 2, 'ka': 2, 'story': 2, 'link': 2, 'punch': 2, 'gut': 2, 'nothing': 2, 'Universe': 2, 'kind': 2, 'happiness': 2, 'question': 2, 'trust': 2, 'anyone': 2, 'email': 2, 'name': 2, 'doesn': 2, 'talent': 2, 'value': 2, 'matter': 2, 'Muskan': 2, 'lot': 2, 'change': 2, 'Tools': 2, 'ChatGPT': 2, 'Expert': 2, 'tools': 2, 'courses': 2, 'reach': 2, 'post': 2, 'messaging': 2, 'customers': 2, 'experience': 2, 'everything': 2, 'life': 2, 'retention': 2, 'content': 2, 'impact': 2, 'Remote': 2, 'future': 2, 'उत्पादकता': 2, 'कुछ': 2, 'empresas': 2, 'sector': 2, "L'innovation": 2, "L'intelligence": 2, 'les': 2, 'solutions': 2, 'innovation': 2, 'et': 2, 'أصبحت': 2, 'إلى': 2, 'فرص': 2, 'أفضل': 2, 'أكثر': 2, 'বৈচিত্র্য': 2, 'গুরুত্বপূর্ণ': 2, 'কর্মক্ষেত্রে': 2, 'আপনার': 2, 'sustentabilidade': 2, 'da': 2, 'mais': 2, 'современном': 2, 'мире': 2, 'требует': 2, 'على': 2, 'الاجتماعات': 2, 'kar': 2, 'Aap': 2, 'healthcare': 2, 'डिजिटल': 2, 'el': 2, 'compétences': 2, 'عالم': 2, 'عصر': 2, 'নতুন': 2, 'pode': 2, 'что': 2, 'вы': 2, 'हुई': 2, 'आपकी': 2, 'ambiental': 2, 'Les': 2, 'changement': 2, 'الذكاء': 2, 'تغيير': 2, 'es': 2, 'Cada': 2, 'تحديات': 2, 'लिए': 2, 'Growth': 1, 'followers': 1, 'platform': 1, 'influencers': 1, 'Jobseekers': 1, 'interview': 1, 'pressure': 1, 'Am': 1, 'isn': 1, 'broken': 1, 'applicants': 1, 'Please': 1, 'care': 1, 'priority': 1, 'dating': 1, 'Full': 1, "'Congratulations": 1, 'catch': 1, 'Pay': 1, 'Rs': 1, 'honor': 1, 'dekhna': 1, 'achi': 1, 'likhna': 1, 'toh': 1, 'nahi': 1, 'line': 1, 'one': 1, 'heart': 1, 'rounds': 1, 'interviews': 1, 'nights': 1, 'preparation': 1, 'way.': 1, '”': 1, 'Every': 1, 'Doors': 1, 'ones': 1, 'values': 1, 'panic': 1, 'plan': 1, 'weight': 1, 'doors': 1, 'path': 1, 'everyone': 1, 'feels': 1, 'study': 1, 'jobseekers': 1, 'anxiety': 1, 'self-doubt': 1, 'search': 1, 'breaks': 1, 'offer': 1, 'letter': 1, 'matters': 1, 'define': 1, '=': 1, 'mindset': 1, 'case': 1, 've': 1, 'privilege': 1, 'dedication': 1, 'title': 1, 'side': 1, 'too—people': 1, 'stuck': 1, 'world': 1, 'Freshers': 1, 'this—skills': 1, 'size': 1, 'craft': 1, 'environment': 1, 'thing': 1, '😯': 1, 'blessing': 1, 'son/daughter': 1, "'great": 1, 'Manager': 1, 'Aura': 1, '+100000000': 1, 'Fictional': 1, 'message': 1, 'sons/daughters': 1, '🙏': 1, 'people/things': 1, 'chain': 1, 'package': 1, 'YouTube': 1, 'sure': 1, 'ad': 1, 'times': 1, 'Can': 1, 'please': 1, 'm': 1, 'career': 1, 'switch': 1, 'See': 1, 'guys': 1, 'hopes': 1, 'tells': 1, 'request': 1, 'don': 1, 'fall': 1, 'Invest': 1, 'expectation': 1, 'resume': 1, 'People': 1, 'writing': 1, 'formula': 1, '+': 1, 'likes': 1, 'talk': 1, 'type': 1, 'means': 1, 'positioning': 1, 'turn': 1, 'connects': 1, '....': 1, 'Well…': 1, 'vacation': 1, 'holiday': 1, 'return': 1, 'days': 1, 'anything': 1, 'amount': 1, 'material': 1, 'validation': 1, 'bank': 1, 'feeling': 1, 'proud': 1, 'pride': 1, 'selfies': 1, 'comfort': 1, 'kids': 1, 'toy': 1, 'store': 1, 'Nothing' ...
# NLTK Verb Frequency: Counter({'is': 22, '’': 15, 'do': 15, 'are': 11, "'s": 10, 'was': 10, 'have': 8, 'don': 8, 'know': 6, 'need': 6, 'get': 5, 'had': 5, 'come': 4, 'be': 4, 'were': 4, 'feel': 4, 's': 4, 'tell': 3, 'hear': 3, 'been': 3, 'felt': 3, 'thought': 3, 'see': 3, 'working': 3, 'told': 3, 'become': 3, 'started': 3, 'كيف': 3, 'help': 2, "'re": 2, 'let': 2, 'remember': 2, 'left': 2, "'ve": 2, 'am': 2, 'looking': 2, 'saying': 2, 'feeling': 2, 'want': 2, 'lost': 2, 'does': 2, 'prove': 2, 'seen': 2, 'Let': 2, 'work': 2, 'improving': 2, 'wish': 2, 'learning': 2, 'use': 2, 'seeing': 2, 'shape': 2, 'making': 2, 'made': 2, 'set': 2, 'say': 2, 'offer': 2, 'retain': 2, 'creating': 2, 'discovered': 2, 'remain': 2, 'que': 2, 'artificielle': 2, 'renouvelables': 2, 'kya': 2, 'has': 2, 'saw': 1, 'written': 1, 'claiming': 1, 'growing': 1, 'copying': 1, 'thinking': 1, 't': 1, 'sacrificing': 1, 'doesn': 1, 'acknowledge': 1, 'taking': 1, 'Looking': 1, 're': 1, 'ghosted': 1, 'selected': 1, 'didn': 1, 'apply': 1, 'sapna': 1, "'interested": 1, 'achi': 1, 'reading': 1, 'starting': 1, 'attached': 1, 'Saves': 1, 'poured': 1, 'realize': 1, 'shown': 1, 'happened': 1, 'wanted': 1, 'walk': 1, 'shut': 1, 'swing': 1, 'aligned': 1, 'stung': 1, 'hurt': 1, 'go': 1, 'planned': 1, 'sit': 1, 'knows': 1, 'waiting': 1, 'Something': 1, 'protecting': 1, 'being': 1, 'cleared': 1, '💔': 1, 'sounds': 1, '🌸': 1, 'According': 1, 'struggle': 1, 'Take': 1, 'define': 1, 'tied': 1, '💥': 1, 'forget': 1, 'caught': 1, 'known': 1, 'blow': 1, 'overwhelmed': 1, 'sees': 1, 'stop': 1, 'attaching': 1, 'doing': 1, 'love': 1, 'gets': 1, 'hope': 1, 'behaves': 1, 'did': 1, 'Thank': 1, 'said': 1, 'offended': 1, 'means': 1, '\ud83e\x0880': 1, 'take': 1, 'treat': 1, 'else': 1, 'Hope': 1, 'like': 1, 'bring': 1, 'break': 1, 'Sounds': 1, 'hiring': 1, 'paying': 1, 'considering': 1, 'Selling': 1, 'isn': 1, 'selling': 1, 'giving': 1, 'land': 1, 'make': 1, 'upskill': 1, 'finds': 1, 'please': 1, 'talk': 1, 'Write': 1, "'well": 1, 'mean': 1, 'liking': 1, 'getting': 1, 'control': 1, 'Defining': 1, 'following': 1, 'informs': 1, 'Your': 1, 'inform': 1, 'Control': 1, 'taught': 1, 'gone': 1, 'turned': 1, 'meditating': 1, 'reflected': 1, 'asking': 1, 'figured': 1, 'match': 1, 'pampering': 1, 'asked': 1, 'travelled': 1, 'stayed': 1, 'act': 1, 'makes': 1, 'experience': 1, 'reducing': 1, 'walked': 1, 'tired': 1, 'lived': 1, 'agree': 1, 'change': 1, 'accept': 1, 'Call': 1, 'visit': 1, 'spend': 1, 'receive': 1, 'subscribing': 1, 'understand': 1, 'survive': 1, 'promote': 1, 'providing': 1, 'retained': 1, 'ask': 1, 'end': 1, 'worry': 1, 'return': 1, 'resonates': 1, 'landed': 1, 'sending': 1, 'read': 1, 'luck': 1, 'happen': 1, 'went': 1, 'worked': 1, 'Posted': 1, 'Documented': 1, 'solved': 1, 'Broke': 1, 'participating': 1, 'publishing': 1, 'breaking': 1, 'solving': 1, 'teaching': 1, 'knew': 1, 'engaging': 1, 'sliding': 1, 'Hiring': 1, 'becoming': 1, 'adopting': 1, 'maintaining': 1, 'ensure': 1, 'operan': 1, 'le': 1, 'من': 1, 'empresas': 1, 'Desde': 1, 'até': 1, 'muito': 1, 'Кризисы': 1, 'Как': 1, 'ولكن': 1, 'kaafi': 1, 'mein': 1, 'ko': 1, 'transforming': 1, 'think': 1, 'inteligencia': 1, 'emplois': 1, 'inquiétudes': 1, 'les': 1, 'dans': 1, 'dominé': 1, 'ما': 1, 'econômicos': 1, 'em': 1, 'А': 1, 'pe': 1, 'kaise': 1, 'aapko': 1, 'create': 1, 'existing': 1, 'replace': 1, 'karega': 1, 'maintain': 1, 'el': 1, 'realmente': 1, 'énergies': 1, 'الاقتصاد؟': 1, 'destruir': 1, 'muitas': 1, 'guide': 1, 'redefined': 1, 'challenges': 1, 'find': 1, 'connect': 1, 'stay': 1, 'found': 1, 'oportunidades': 1, '¿Cuál': 1, 'technologies': 1, 'émergentes': 1, 'défis': 1, 'كل': 1, 'apenas': 1, 'e': 1, 'fazer': 1, 'Какие': 1, 'ka': 1, 'banana': 1, 'contribute': 1, 'reshaping': 1, 'leveraging': 1, 'emerging': 1, 'drive': 1, 'ante': 1, 'essentielles': 1, 'pour': 1, 'العالم': 1})
